# %%
import numpy as np
import pandas as pd

# %%
data = {
    'Name' : ['Piku','kungfu','kunu','lama'],
    'Age' : [23,25,31,33],
    'Country' : ['Turky','London','Dubai','Bali'],
    'salary': [65000,50000,45000,11110]
}

df = pd.DataFrame(data)
df
# Out:
#      Name  Age Country  salary
# 0    Piku   23   Turky   65000
# 1  kungfu   25  London   50000
# 2    kunu   31   Dubai   45000
# 3    lama   33    Bali   11110

# %%
data_list = [
    ['Piku', 23, 'Turky', 65000],
    ['kungfu', 25,'London',	50000],
    ['kunu', 31,'Dubai', 45000],
    ['lama', 33, 'Bali', 11110]
]
column = ['name','age','country','salary']
df2 = pd.DataFrame(data_list,columns=column)
df2
# Out:
#      name  age country  salary
# 0    Piku   23   Turky   65000
# 1  kungfu   25  London   50000
# 2    kunu   31   Dubai   45000
# 3    lama   33    Bali   11110

# %%
df
# Out:
#      Name  Age Country  salary
# 0    Piku   23   Turky   65000
# 1  kungfu   25  London   50000
# 2    kunu   31   Dubai   45000
# 3    lama   33    Bali   11110

# %%
df[['Name','Country']]                                     #selecting colomuns
# Out:
#      Name Country
# 0    Piku   Turky
# 1  kungfu  London
# 2    kunu   Dubai
# 3    lama    Bali

# %%
df["profession"] = ["Data Science","Web developer","UI/UX Designer","Game Developer"]
df                                       #creating columns
# Out:
#      Name  Age Country  salary      profession
# 0    Piku   23   Turky   65000    Data Science
# 1  kungfu   25  London   50000   Web developer
# 2    kunu   31   Dubai   45000  UI/UX Designer
# 3    lama   33    Bali   11110  Game Developer

# %%
df.drop(["profession"],axis=1,inplace=True)             #removing columns

# %%
df
# Out:
#      Name  Age Country  salary
# 0    Piku   23   Turky   65000
# 1  kungfu   25  London   50000
# 2    kunu   31   Dubai   45000
# 3    lama   33    Bali   11110

# %%
df.drop([1],axis=0)                                 #removing rows
# Out:
#    Name  Age Country  salary
# 0  Piku   23   Turky   65000
# 2  kunu   31   Dubai   45000
# 3  lama   33    Bali   11110

# %%
df
# Out:
#      Name  Age Country  salary
# 0    Piku   23   Turky   65000
# 1  kungfu   25  London   50000
# 2    kunu   31   Dubai   45000
# 3    lama   33    Bali   11110

# %%
df2
# Out:
#      name  age country  salary
# 0    Piku   23   Turky   65000
# 1  kungfu   25  London   50000
# 2    kunu   31   Dubai   45000
# 3    lama   33    Bali   11110

# %%
#selecting rows
df2.loc[[1]]
# Out:
#      name  age country  salary
# 1  kungfu   25  London   50000

# %%
df2.loc[[0,1]][["name","salary"]]
# Out:
#      name  salary
# 0    Piku   65000
# 1  kungfu   50000

# %%
df2.loc[[2,3]][["name","age"]]
# Out:
#    name  age
# 2  kunu   31
# 3  lama   33

# %%
df
# Out:
#      Name  Age Country  salary
# 0    Piku   23   Turky   65000
# 1  kungfu   25  London   50000
# 2    kunu   31   Dubai   45000
# 3    lama   33    Bali   11110

# %%
#conditional selection 
df[df["Age"]>30]
# Out:
#    Name  Age Country  salary
# 2  kunu   31   Dubai   45000
# 3  lama   33    Bali   11110

# %%
#conditional selection for two conditions
df[(df['Age']>30) & (df['Country'] == 'Bali')]
# Out:
#    Name  Age Country  salary
# 3  lama   33    Bali   11110
