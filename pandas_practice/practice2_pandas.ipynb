# %%
import numpy as np
import pandas as pd

# %%
name = ["Rinku","Riya","Kunal"]
age = [20,21,22]

# %%
df = pd.DataFrame({
    "Name" : name,
    "Age" : age
})
print(data)
# Out:
#     Name  Age
# 0  Rinku   20
# 1   Riya   21
# 2  Kunal   22

# %%
df.shape
# Out:
# (3, 2)

# %%
df.columns
# Out:
# Index(['Name', 'Age'], dtype='object')

# %%
df.head()
# Out:
#     Name  Age
# 0  Rinku   20
# 1   Riya   21
# 2  Kunal   22

# %%
df[["Name"]]
# Out:
#     Name
# 0  Rinku
# 1   Riya
# 2  Kunal

# %%
df["Marks"] = [90,85,88]
df
# Out:
#     Name  Age  Marks
# 0  Rinku   20     90
# 1   Riya   21     85
# 2  Kunal   22     88

# %%
df[df["Age"]>20]
# Out:
#     Name  Age  Marks
# 1   Riya   21     85
# 2  Kunal   22     88

# %%
df[df["Marks"]>85]
# Out:
#     Name  Age  Marks
# 0  Rinku   20     90
# 2  Kunal   22     88

# %%
df.describe()
# Out:
#         Age      Marks
# count   3.0   3.000000
# mean   21.0  87.666667
# std     1.0   2.516611
# min    20.0  85.000000
# 25%    20.5  86.500000
# 50%    21.0  88.000000
# 75%    21.5  89.000000
# max    22.0  90.000000

# %%
df
# Out:
#     Name  Age  Marks
# 0  Rinku   20     90
# 1   Riya   21     85
# 2  Kunal   22     88

# %%
df["Marks"].mean()
# Out:
# np.float64(87.66666666666667)

# %%
df.sort_values("Marks")
# Out:
#     Name  Age  Marks
# 1   Riya   21     85
# 2  Kunal   22     88
# 0  Rinku   20     90

# %%
data1 = pd.DataFrame({
    "Name" : ['A','B','C'],
    "Math" : [90,70,80],
    "Science" : [85,95,76]
})
data1
# Out:
#   Name  Math  Science
# 0    A    90       85
# 1    B    70       95
# 2    C    80       76

# %%
data1["Math"].mean()
# Out:
# np.float64(80.0)

# %%
data1["Math"].max()
# Out:
# np.int64(90)

# %%
data1[data1["Math"]>80]
# Out:
#   Name  Math  Science
# 0    A    90       85
