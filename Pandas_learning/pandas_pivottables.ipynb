# %%
import numpy as np
import pandas as pd

# %%
data = {
    'Date': pd.date_range('2023-01-01', periods=20),
    'Product': ['A', 'B', 'C', 'D'] * 5,
    'Region': ['East', 'West', 'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West',
               'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West', 'North', 'South'],
    'Sales': np.random.randint(100, 1000, 20),
    'Units': np.random.randint(10, 100, 20),
    'Rep': ['John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary',
            'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice']
}

# %%
df = pd.DataFrame(data)

df['Month'] = df['Date'].dt.month_name()
df['Quarter'] = 'Q' + df['Date'].dt.quarter.astype(str)
df
# Out:
#          Date Product Region  Sales  Units    Rep    Month Quarter
# 0  2023-01-01       A   East    793     74   John  January      Q1
# 1  2023-01-02       B   West    992     58   Mary  January      Q1
# 2  2023-01-03       C  North    677     50    Bob  January      Q1
# 3  2023-01-04       D  South    652     24  Alice  January      Q1
# 4  2023-01-05       A   East    925     27   John  January      Q1
# 5  2023-01-06       B   West    833     44   Mary  January      Q1
# 6  2023-01-07       C  North    106     81    Bob  January      Q1
# 7  2023-01-08       D  South    628     27  Alice  January      Q1
# 8  2023-01-09       A   East    959     51   John  January      Q1
# 9  2023-01-10       B   West    869     87   Mary  January      Q1
# 10 2023-01-11       C  North    464     93    Bob  January      Q1
# 11 2023-01-12       D  South    561     13  Alice  January      Q1
# 12 2023-01-13       A   East    686     25   John  January      Q1
# 13 2023-01-14       B   West    998     80   Mary  January      Q1
# 14 2023-01-15       C  North    326     57    Bob  January      Q1
# 15 2023-01-16       D  South    682     25  Alice  January      Q1
# 16 2023-01-17       A   East    722     29   John  January      Q1
# 17 2023-01-18       B   West    902     40   Mary  January      Q1
# 18 2023-01-19       C  North    444     95    Bob  January      Q1
# 19 2023-01-20       D  South    238     42  Alice  January      Q1

# %%
pivot = pd.pivot_table(                                            #TO CUSTIMIZE DATA ACCORDING TO YOU
                       df,
                       values='Sales',
                       index='Region',
                       columns='Product',
                       aggfunc='mean'
                      )
pivot
# Out:
# Product      A      B      C      D
# Region
# East     817.0    NaN    NaN    NaN
# North      NaN    NaN  403.4    NaN
# South      NaN    NaN    NaN  552.2
# West       NaN  918.8    NaN    NaN

# %%
pivot2 = pd.pivot_table(df,                                           
                        values=['Sales','Units'],
                        index = 'Region',
                        columns = 'Product'
)
pivot2
# Out:
#          Sales                      Units
# Product      A      B      C      D     A     B     C     D
# Region
# East     817.0    NaN    NaN    NaN  41.2   NaN   NaN   NaN
# North      NaN    NaN  403.4    NaN   NaN   NaN  75.2   NaN
# South      NaN    NaN    NaN  552.2   NaN   NaN   NaN  26.2
# West       NaN  918.8    NaN    NaN   NaN  61.8   NaN   NaN

# %%
pd.crosstab(df['Region'],df['Product'])                                   #FOR COUNTING PURPOSE
# Out:
# Product  A  B  C  D
# Region
# East     5  0  0  0
# North    0  0  5  0
# South    0  0  0  5
# West     0  5  0  0
