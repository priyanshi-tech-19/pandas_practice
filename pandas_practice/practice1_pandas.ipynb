# %%
import numpy as np
import pandas as pd

# %%
s = pd.Series([10,20,30,40,50])
print(s)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
s1 = pd.Series(["Aman","Riya","Kunal","Priya"])
print(s1)
# Out:
# 0     Aman
# 1     Riya
# 2    Kunal
# 3    Priya
# dtype: object

# %%
s1[[0,3]]
# Out:
# 0     Aman
# 3    Priya
# dtype: object

# %%
s
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
np.max(s)
# Out:
# np.int64(50)

# %%
np.min(s)
# Out:
# np.int64(10)

# %%
np.mean(s)
# Out:
# np.float64(30.0)

# %%
sub = ["math","science","english"]
marks = [90,85,88]
pd.Series(marks,index=sub)
# Out:
# math       90
# science    85
# english    88
# dtype: int64
