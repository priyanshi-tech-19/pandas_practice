# %%
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame({
    'Name':['A','B','C','D'],
    'Marks':[90,np.nan,85,np.nan]
})

df
# Out:
#   Name  Marks
# 0    A   90.0
# 1    B    NaN
# 2    C   85.0
# 3    D    NaN

# %%
df.isna()
# Out:
#     Name  Marks
# 0  False  False
# 1  False   True
# 2  False  False
# 3  False   True

# %%
df.fillna(0)
# Out:
#   Name  Marks
# 0    A   90.0
# 1    B    0.0
# 2    C   85.0
# 3    D    0.0

# %%
df = pd.DataFrame({
    'A':[1,2,np.nan,4],
    'B':[np.nan,5,6,7]
})
df
# Out:
#      A    B
# 0  1.0  NaN
# 1  2.0  5.0
# 2  NaN  6.0
# 3  4.0  7.0

# %%
df.isna().sum()
# Out:
# A    1
# B    1
# dtype: int64

# %%
df.dropna()
# Out:
#      A    B
# 1  2.0  5.0
# 3  4.0  7.0

# %%
df = pd.DataFrame({
    'Math':[90,np.nan,80],
    'Science':[70,60,np.nan]
})

# %%
df
# Out:
#    Math  Science
# 0  90.0     70.0
# 1   NaN     60.0
# 2  80.0      NaN

# %%
df.fillna({'Math':100,'Science':50})
# Out:
#     Math  Science
# 0   90.0     70.0
# 1  100.0     60.0
# 2   80.0     50.0

# %%
df = pd.DataFrame({
    'A':[1,np.nan,3],
    'B':[4,5,np.nan],
    'C':[7,8,9]
})

# %%
df.isnull().sum().sum()
# Out:
# np.int64(2)

# %%
df = pd.DataFrame({
    'Name':['Ram',np.nan,'Mohan'],
    'Age':[20,21,np.nan]
})

# %%
df['Age'].mean()
# Out:
# np.float64(20.5)

# %%
df.fillna({"Name":"unknown","Age":df['Age'].mean()})
# Out:
#       Name   Age
# 0      Ram  20.0
# 1  unknown  21.0
# 2    Mohan  20.5

# %%
df = pd.DataFrame({
    'A':[1,np.nan,np.nan],
    'B':[4,5,np.nan],
    'C':[7,8,9]
})

# %%
df
# Out:
#      A    B  C
# 0  1.0  4.0  7
# 1  NaN  5.0  8
# 2  NaN  NaN  9

# %%
df.dropna(how = 'all')
# Out:
#      A    B  C
# 0  1.0  4.0  7
# 1  NaN  5.0  8
# 2  NaN  NaN  9
